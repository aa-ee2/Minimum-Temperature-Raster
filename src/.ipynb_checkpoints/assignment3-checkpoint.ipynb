# %%
# !pip install --upgrade pip
# !pip install --force-reinstall geopandas rasterio rioxarray rasterstats shapely pyproj matplotlib pandas numpy folium
# Out:
# Requirement already satisfied: pip in c:\users\dell\anaconda3\envs\tarea3python311\lib\site-packages (25.2)
# Collecting geopandas
#   Using cached geopandas-1.1.1-py3-none-any.whl.metadata (2.3 kB)
# Collecting rasterio
#   Using cached rasterio-1.4.3-cp311-cp311-win_amd64.whl.metadata (9.4 kB)
# Collecting rioxarray
#   Using cached rioxarray-0.19.0-py3-none-any.whl.metadata (5.5 kB)
# Collecting rasterstats
#   Using cached rasterstats-0.20.0-py3-none-any.whl.metadata (4.2 kB)
# Collecting shapely
#   Using cached shapely-2.1.2-cp311-cp311-win_amd64.whl.metadata (7.1 kB)
# Collecting pyproj
#   Using cached pyproj-3.7.2-cp311-cp311-win_amd64.whl.metadata (31 kB)
# Collecting matplotlib
#   Using cached matplotlib-3.10.7-cp311-cp311-win_amd64.whl.metadata (11 kB)
# Collecting pandas
#   Using cached pandas-2.3.3-cp311-cp311-win_amd64.whl.metadata (19 kB)
# Collecting numpy
#   Using cached numpy-2.3.4-cp311-cp311-win_amd64.whl.metadata (60 kB)
# Collecting folium
#   Using cached folium-0.20.0-py2.py3-none-any.whl.metadata (4.2 kB)
# Collecting pyogrio>=0.7.2 (from geopandas)
#   Using cached pyogrio-0.11.1-cp311-cp311-win_amd64.whl.metadata (5.4 kB)
# Collecting packaging (from geopandas)
#   Using cached packaging-25.0-py3-none-any.whl.metadata (3.3 kB)
# Collecting affine (from rasterio)
#   Using cached affine-2.4.0-py3-none-any.whl.metadata (4.0 kB)
# Collecting attrs (from rasterio)
#   Using cached attrs-25.4.0-py3-none-any.whl.metadata (10 kB)
# Collecting certifi (from rasterio)
#   Using cached certifi-2025.10.5-py3-none-any.whl.metadata (2.5 kB)
# Collecting click>=4.0 (from rasterio)
#   Using cached click-8.3.0-py3-none-any.whl.metadata (2.6 kB)
# Collecting cligj>=0.5 (from rasterio)
#   Using cached cligj-0.7.2-py3-none-any.whl.metadata (5.0 kB)
# Collecting click-plugins (from rasterio)
#   Using cached click_plugins-1.1.1.2-py2.py3-none-any.whl.metadata (6.5 kB)
# Collecting pyparsing (from rasterio)
#   Using cached pyparsing-3.2.5-py3-none-any.whl.metadata (5.0 kB)
# Collecting xarray>=2024.7.0 (from rioxarray)
#   Using cached xarray-2025.10.1-py3-none-any.whl.metadata (12 kB)
# Collecting fiona (from rasterstats)
#   Using cached fiona-1.10.1-cp311-cp311-win_amd64.whl.metadata (58 kB)
# Collecting simplejson (from rasterstats)
#   Using cached simplejson-3.20.2-cp311-cp311-win_amd64.whl.metadata (3.4 kB)
# Collecting contourpy>=1.0.1 (from matplotlib)
#   Using cached contourpy-1.3.3-cp311-cp311-win_amd64.whl.metadata (5.5 kB)
# Collecting cycler>=0.10 (from matplotlib)
#   Using cached cycler-0.12.1-py3-none-any.whl.metadata (3.8 kB)
# Collecting fonttools>=4.22.0 (from matplotlib)
#   Using cached fonttools-4.60.1-cp311-cp311-win_amd64.whl.metadata (114 kB)
# Collecting kiwisolver>=1.3.1 (from matplotlib)
#   Using cached kiwisolver-1.4.9-cp311-cp311-win_amd64.whl.metadata (6.4 kB)
# Collecting pillow>=8 (from matplotlib)
#   Using cached pillow-12.0.0-cp311-cp311-win_amd64.whl.metadata (9.0 kB)
# Collecting python-dateutil>=2.7 (from matplotlib)
#   Using cached python_dateutil-2.9.0.post0-py2.py3-none-any.whl.metadata (8.4 kB)
# Collecting pytz>=2020.1 (from pandas)
#   Using cached pytz-2025.2-py2.py3-none-any.whl.metadata (22 kB)
# Collecting tzdata>=2022.7 (from pandas)
#   Using cached tzdata-2025.2-py2.py3-none-any.whl.metadata (1.4 kB)
# Collecting branca>=0.6.0 (from folium)
#   Using cached branca-0.8.2-py3-none-any.whl.metadata (1.7 kB)
# Collecting jinja2>=2.9 (from folium)
#   Using cached jinja2-3.1.6-py3-none-any.whl.metadata (2.9 kB)
# Collecting requests (from folium)
#   Using cached requests-2.32.5-py3-none-any.whl.metadata (4.9 kB)
# Collecting xyzservices (from folium)
#   Using cached xyzservices-2025.4.0-py3-none-any.whl.metadata (4.3 kB)
# Collecting colorama (from click>=4.0->rasterio)
#   Using cached colorama-0.4.6-py2.py3-none-any.whl.metadata (17 kB)
# Collecting MarkupSafe>=2.0 (from jinja2>=2.9->folium)
#   Using cached markupsafe-3.0.3-cp311-cp311-win_amd64.whl.metadata (2.8 kB)
# Collecting six>=1.5 (from python-dateutil>=2.7->matplotlib)
#   Using cached six-1.17.0-py2.py3-none-any.whl.metadata (1.7 kB)
# Collecting charset_normalizer<4,>=2 (from requests->folium)
#   Using cached charset_normalizer-3.4.4-cp311-cp311-win_amd64.whl.metadata (38 kB)
# Collecting idna<4,>=2.5 (from requests->folium)
#   Using cached idna-3.11-py3-none-any.whl.metadata (8.4 kB)
# Collecting urllib3<3,>=1.21.1 (from requests->folium)
#   Using cached urllib3-2.5.0-py3-none-any.whl.metadata (6.5 kB)
# Using cached geopandas-1.1.1-py3-none-any.whl (338 kB)
# Using cached rasterio-1.4.3-cp311-cp311-win_amd64.whl (25.5 MB)
# Using cached rioxarray-0.19.0-py3-none-any.whl (62 kB)
# Using cached rasterstats-0.20.0-py3-none-any.whl (17 kB)
# Using cached shapely-2.1.2-cp311-cp311-win_amd64.whl (1.7 MB)
# Using cached pyproj-3.7.2-cp311-cp311-win_amd64.whl (6.3 MB)
# Using cached matplotlib-3.10.7-cp311-cp311-win_amd64.whl (8.1 MB)
# Using cached pandas-2.3.3-cp311-cp311-win_amd64.whl (11.3 MB)
# Using cached numpy-2.3.4-cp311-cp311-win_amd64.whl (13.1 MB)
# Using cached folium-0.20.0-py2.py3-none-any.whl (113 kB)
# Using cached branca-0.8.2-py3-none-any.whl (26 kB)
# Using cached click-8.3.0-py3-none-any.whl (107 kB)
# Using cached cligj-0.7.2-py3-none-any.whl (7.1 kB)
# Using cached contourpy-1.3.3-cp311-cp311-win_amd64.whl (225 kB)
# Using cached cycler-0.12.1-py3-none-any.whl (8.3 kB)
# Using cached fonttools-4.60.1-cp311-cp311-win_amd64.whl (2.3 MB)
# Using cached jinja2-3.1.6-py3-none-any.whl (134 kB)
# Using cached kiwisolver-1.4.9-cp311-cp311-win_amd64.whl (73 kB)
# Using cached markupsafe-3.0.3-cp311-cp311-win_amd64.whl (15 kB)
# Using cached packaging-25.0-py3-none-any.whl (66 kB)
# Using cached pillow-12.0.0-cp311-cp311-win_amd64.whl (7.0 MB)
# Using cached pyogrio-0.11.1-cp311-cp311-win_amd64.whl (19.2 MB)
# Using cached pyparsing-3.2.5-py3-none-any.whl (113 kB)
# Using cached python_dateutil-2.9.0.post0-py2.py3-none-any.whl (229 kB)
# Using cached pytz-2025.2-py2.py3-none-any.whl (509 kB)
# Using cached six-1.17.0-py2.py3-none-any.whl (11 kB)
# Using cached tzdata-2025.2-py2.py3-none-any.whl (347 kB)
# Using cached xarray-2025.10.1-py3-none-any.whl (1.4 MB)
# Using cached affine-2.4.0-py3-none-any.whl (15 kB)
# Using cached attrs-25.4.0-py3-none-any.whl (67 kB)
# Using cached certifi-2025.10.5-py3-none-any.whl (163 kB)
# Using cached click_plugins-1.1.1.2-py2.py3-none-any.whl (11 kB)
# Using cached colorama-0.4.6-py2.py3-none-any.whl (25 kB)
# Using cached fiona-1.10.1-cp311-cp311-win_amd64.whl (24.5 MB)
# Using cached requests-2.32.5-py3-none-any.whl (64 kB)
# Using cached charset_normalizer-3.4.4-cp311-cp311-win_amd64.whl (106 kB)
# Using cached idna-3.11-py3-none-any.whl (71 kB)
# Using cached urllib3-2.5.0-py3-none-any.whl (129 kB)
# Using cached simplejson-3.20.2-cp311-cp311-win_amd64.whl (75 kB)
# Using cached xyzservices-2025.4.0-py3-none-any.whl (90 kB)
# Installing collected packages: pytz, xyzservices, urllib3, tzdata, six, simplejson, pyparsing, pillow, packaging, numpy, MarkupSafe, kiwisolver, idna, fonttools, cycler, colorama, charset_normalizer, certifi, attrs, affine, shapely, requests, python-dateutil, pyproj, pyogrio, jinja2, contourpy, click, pandas, matplotlib, cligj, click-plugins, branca, xarray, rasterio, geopandas, folium, fiona, rioxarray, rasterstats
#
#   Attempting uninstall: pytz
#
#     Found existing installation: pytz 2025.2
#
#     Uninstalling pytz-2025.2:
#
#       Successfully uninstalled pytz-2025.2
#
#    ----------------------------------------  0/40 [pytz]
#    ----------------------------------------  0/40 [pytz]
#    ----------------------------------------  0/40 [pytz]
#   Attempting uninstall: xyzservices
#    ----------------------------------------  0/40 [pytz]
#     Found existing installation: xyzservices 2025.4.0
#    ----------------------------------------  0/40 [pytz]
#     Uninstalling xyzservices-2025.4.0:
#    ----------------------------------------  0/40 [pytz]
#       Successfully uninstalled xyzservices-2025.4.0
#    ----------------------------------------  0/40 [pytz]
#   Attempting uninstall: urllib3
#    ----------------------------------------  0/40 [pytz]
#     Found existing installation: urllib3 2.5.0
#    ----------------------------------------  0/40 [pytz]
#    -- -------------------------------------  2/40 [urllib3]
#     Uninstalling urllib3-2.5.0:
#    -- -------------------------------------  2/40 [urllib3]
#       Successfully uninstalled urllib3-2.5.0
#    -- -------------------------------------  2/40 [urllib3]
#    -- -------------------------------------  2/40 [urllib3]
#   Attempting uninstall: tzdata
#    -- -------------------------------------  2/40 [urllib3]
#     Found existing installation: tzdata 2025.2
#    -- -------------------------------------  2/40 [urllib3]
#     Uninstalling tzdata-2025.2:
#    -- -------------------------------------  2/40 [urllib3]
#    --- ------------------------------------  3/40 [tzdata]
#       Successfully uninstalled tzdata-2025.2
#    --- ------------------------------------  3/40 [tzdata]
#    --- ------------------------------------  3/40 [tzdata]
#    --- ------------------------------------  3/40 [tzdata]
#   Attempting uninstall: six
#    --- ------------------------------------  3/40 [tzdata]
#     Found existing installation: six 1.17.0
#    --- ------------------------------------  3/40 [tzdata]
#     Uninstalling six-1.17.0:
#    --- ------------------------------------  3/40 [tzdata]
#    ---- -----------------------------------  4/40 [six]
#    ---- -----------------------------------  4/40 [six]
#    ---- -----------------------------------  4/40 [six]
#    ---- -----------------------------------  4/40 [six]
#    ---- -----------------------------------  4/40 [six]
#    ---- -----------------------------------  4/40 [six]
#    ---- -----------------------------------  4/40 [six]
#    ---- -----------------------------------  4/40 [six]
#    ---- -----------------------------------  4/40 [six]
#    ---- -----------------------------------  4/40 [six]
#    ---- -----------------------------------  4/40 [six]
#    ---- -----------------------------------  4/40 [six]
#    ---- -----------------------------------  4/40 [six]
#    ---- -----------------------------------  4/40 [six]
#    ---- -----------------------------------  4/40 [six]
#    ---- -----------------------------------  4/40 [six]
#    ---- -----------------------------------  4/40 [six]
#       Successfully uninstalled six-1.17.0
#    ---- -----------------------------------  4/40 [six]
#   Attempting uninstall: simplejson
#    ---- -----------------------------------  4/40 [six]
#     Found existing installation: simplejson 3.20.2
#    ---- -----------------------------------  4/40 [six]
#    ----- ----------------------------------  5/40 [simplejson]
#     Uninstalling simplejson-3.20.2:
#    ----- ----------------------------------  5/40 [simplejson]
#       Successfully uninstalled simplejson-3.20.2
#    ----- ----------------------------------  5/40 [simplejson]
#    ----- ----------------------------------  5/40 [simplejson]
#    ----- ----------------------------------  5/40 [simplejson]
#    ----- ----------------------------------  5/40 [simplejson]
#    ----- ----------------------------------  5/40 [simplejson]
#    ----- ----------------------------------  5/40 [simplejson]
#    ----- ----------------------------------  5/40 [simplejson]
#    ----- ----------------------------------  5/40 [simplejson]
#    ----- ----------------------------------  5/40 [simplejson]
#    ----- ----------------------------------  5/40 [simplejson]
#    ----- ----------------------------------  5/40 [simplejson]
#    ----- ----------------------------------  5/40 [simplejson]
#    ----- ----------------------------------  5/40 [simplejson]
#    ----- ----------------------------------  5/40 [simplejson]
#    ----- ----------------------------------  5/40 [simplejson]
#    ----- ----------------------------------  5/40 [simplejson]
#    ----- ----------------------------------  5/40 [simplejson]
#    ----- ----------------------------------  5/40 [simplejson]
#    ----- ----------------------------------  5/40 [simplejson]
#   Attempting uninstall: pyparsing
#    ----- ----------------------------------  5/40 [simplejson]
#     Found existing installation: pyparsing 3.2.5
#    ----- ----------------------------------  5/40 [simplejson]
#    ------ ---------------------------------  6/40 [pyparsing]
#     Uninstalling pyparsing-3.2.5:
#    ------ ---------------------------------  6/40 [pyparsing]
#       Successfully uninstalled pyparsing-3.2.5
#    ------ ---------------------------------  6/40 [pyparsing]
#   Attempting uninstall: pillow
#    ------ ---------------------------------  6/40 [pyparsing]
#     Found existing installation: pillow 10.4.0
#    ------ ---------------------------------  6/40 [pyparsing]
#     Uninstalling pillow-10.4.0:
#    ------ ---------------------------------  6/40 [pyparsing]
#    ------- --------------------------------  7/40 [pillow]
#       Successfully uninstalled pillow-10.4.0
#    ------- --------------------------------  7/40 [pillow]
#    ------- --------------------------------  7/40 [pillow]
#    ------- --------------------------------  7/40 [pillow]
#    ------- --------------------------------  7/40 [pillow]
#    ------- --------------------------------  7/40 [pillow]
#    ------- --------------------------------  7/40 [pillow]
#    ------- --------------------------------  7/40 [pillow]
#    ------- --------------------------------  7/40 [pillow]
#    ------- --------------------------------  7/40 [pillow]
#    ------- --------------------------------  7/40 [pillow]
#    ------- --------------------------------  7/40 [pillow]
#    ------- --------------------------------  7/40 [pillow]
#    ------- --------------------------------  7/40 [pillow]
#    ------- --------------------------------  7/40 [pillow]
#    ------- --------------------------------  7/40 [pillow]
#    ------- --------------------------------  7/40 [pillow]
#    ------- --------------------------------  7/40 [pillow]
#    ------- --------------------------------  7/40 [pillow]
#    ------- --------------------------------  7/40 [pillow]
#    ------- --------------------------------  7/40 [pillow]
#    ------- --------------------------------  7/40 [pillow]
#   Attempting uninstall: packaging
#    ------- --------------------------------  7/40 [pillow]
#     Found existing installation: packaging 24.2
#    ------- --------------------------------  7/40 [pillow]
#    -------- -------------------------------  8/40 [packaging]
#     Uninstalling packaging-24.2:
#    -------- -------------------------------  8/40 [packaging]
#       Successfully uninstalled packaging-24.2
#    -------- -------------------------------  8/40 [packaging]
#   Attempting uninstall: numpy
#    -------- -------------------------------  8/40 [packaging]
#     Found existing installation: numpy 1.26.4
#    -------- -------------------------------  8/40 [packaging]
#    --------- ------------------------------  9/40 [numpy]
#     Uninstalling numpy-1.26.4:
#    --------- ------------------------------  9/40 [numpy]
#    --------- ------------------------------  9/40 [numpy]
#    --------- ------------------------------  9/40 [numpy]
#    --------- ------------------------------  9/40 [numpy]
#    --------- ------------------------------  9/40 [numpy]
#    --------- ------------------------------  9/40 [numpy]
#    --------- ------------------------------  9/40 [numpy]
#    --------- ------------------------------  9/40 [numpy]
#       Successfully uninstalled numpy-1.26.4
#    --------- ------------------------------  9/40 [numpy]
#    --------- ------------------------------  9/40 [numpy]
#    --------- ------------------------------  9/40 [numpy]
#    --------- ------------------------------  9/40 [numpy]
#    --------- ------------------------------  9/40 [numpy]
#    --------- ------------------------------  9/40 [numpy]
#    --------- ------------------------------  9/40 [numpy]
#    --------- ------------------------------  9/40 [numpy]
#    --------- ------------------------------  9/40 [numpy]
#    --------- ------------------------------  9/40 [numpy]
#    --------- ------------------------------  9/40 [numpy]
#    --------- ------------------------------  9/40 [numpy]
#    --------- ------------------------------  9/40 [numpy]
#    --------- ------------------------------  9/40 [numpy]
#    --------- ------------------------------  9/40 [numpy]
#    --------- ------------------------------  9/40 [numpy]
#    --------- ------------------------------  9/40 [numpy]
#    --------- ------------------------------  9/40 [numpy]
#    --------- ------------------------------  9/40 [numpy]
#    --------- ------------------------------  9/40 [numpy]
#    --------- ------------------------------  9/40 [numpy]
#    --------- ------------------------------  9/40 [numpy]
#    --------- ------------------------------  9/40 [numpy]
#    --------- ------------------------------  9/40 [numpy]
#    --------- ------------------------------  9/40 [numpy]
#    --------- ------------------------------  9/40 [numpy]
#    --------- ------------------------------  9/40 [numpy]
#    --------- ------------------------------  9/40 [numpy]
#    --------- ------------------------------  9/40 [numpy]
#    --------- ------------------------------  9/40 [numpy]
#    --------- ------------------------------  9/40 [numpy]
#    --------- ------------------------------  9/40 [numpy]
#    --------- ------------------------------  9/40 [numpy]
#    --------- ------------------------------  9/40 [numpy]
#    --------- ------------------------------  9/40 [numpy]
#    --------- ------------------------------  9/40 [numpy]
#    --------- ------------------------------  9/40 [numpy]
#    --------- ------------------------------  9/40 [numpy]
#    --------- ------------------------------  9/40 [numpy]
#    --------- ------------------------------  9/40 [numpy]
#    --------- ------------------------------  9/40 [numpy]
#    --------- ------------------------------  9/40 [numpy]
#    --------- ------------------------------  9/40 [numpy]
#    --------- ------------------------------  9/40 [numpy]
#    --------- ------------------------------  9/40 [numpy]
#    --------- ------------------------------  9/40 [numpy]
#    --------- ------------------------------  9/40 [numpy]
#    --------- ------------------------------  9/40 [numpy]
#    --------- ------------------------------  9/40 [numpy]
#    --------- ------------------------------  9/40 [numpy]
#    --------- ------------------------------  9/40 [numpy]
#    --------- ------------------------------  9/40 [numpy]
#    --------- ------------------------------  9/40 [numpy]
#    --------- ------------------------------  9/40 [numpy]
#    --------- ------------------------------  9/40 [numpy]
#   Attempting uninstall: MarkupSafe
#    --------- ------------------------------  9/40 [numpy]
#    ---------- ----------------------------- 10/40 [MarkupSafe]
#     Found existing installation: MarkupSafe 3.0.3
#    ---------- ----------------------------- 10/40 [MarkupSafe]
#     Uninstalling MarkupSafe-3.0.3:
#    ---------- ----------------------------- 10/40 [MarkupSafe]
#       Successfully uninstalled MarkupSafe-3.0.3
#    ---------- ----------------------------- 10/40 [MarkupSafe]
#    ---------- ----------------------------- 10/40 [MarkupSafe]
#    ---------- ----------------------------- 10/40 [MarkupSafe]
#    ---------- ----------------------------- 10/40 [MarkupSafe]
#    ---------- ----------------------------- 10/40 [MarkupSafe]
#    ---------- ----------------------------- 10/40 [MarkupSafe]
#    ---------- ----------------------------- 10/40 [MarkupSafe]
#    ---------- ----------------------------- 10/40 [MarkupSafe]
#    ---------- ----------------------------- 10/40 [MarkupSafe]
#    ---------- ----------------------------- 10/40 [MarkupSafe]
#    ---------- ----------------------------- 10/40 [MarkupSafe]
#    ---------- ----------------------------- 10/40 [MarkupSafe]
#    ---------- ----------------------------- 10/40 [MarkupSafe]
#    ---------- ----------------------------- 10/40 [MarkupSafe]
#    ---------- ----------------------------- 10/40 [MarkupSafe]
#    ---------- ----------------------------- 10/40 [MarkupSafe]
#    ---------- ----------------------------- 10/40 [MarkupSafe]
#    ---------- ----------------------------- 10/40 [MarkupSafe]
#   Attempting uninstall: kiwisolver
#    ---------- ----------------------------- 10/40 [MarkupSafe]
#     Found existing installation: kiwisolver 1.4.9
#    ---------- ----------------------------- 10/40 [MarkupSafe]
#     Uninstalling kiwisolver-1.4.9:
#    ---------- ----------------------------- 10/40 [MarkupSafe]
#       Successfully uninstalled kiwisolver-1.4.9
#    ---------- ----------------------------- 10/40 [MarkupSafe]
#    ----------- ---------------------------- 11/40 [kiwisolver]
#    ----------- ---------------------------- 11/40 [kiwisolver]
#    ----------- ---------------------------- 11/40 [kiwisolver]
#    ----------- ---------------------------- 11/40 [kiwisolver]
#    ----------- ---------------------------- 11/40 [kiwisolver]
#    ----------- ---------------------------- 11/40 [kiwisolver]
#    ----------- ---------------------------- 11/40 [kiwisolver]
#    ----------- ---------------------------- 11/40 [kiwisolver]
#    ----------- ---------------------------- 11/40 [kiwisolver]
#    ----------- ---------------------------- 11/40 [kiwisolver]
#    ----------- ---------------------------- 11/40 [kiwisolver]
#    ----------- ---------------------------- 11/40 [kiwisolver]
#    ----------- ---------------------------- 11/40 [kiwisolver]
#    ----------- ---------------------------- 11/40 [kiwisolver]
#    ----------- ---------------------------- 11/40 [kiwisolver]
#    ----------- ---------------------------- 11/40 [kiwisolver]
#    ----------- ---------------------------- 11/40 [kiwisolver]
#    ----------- ---------------------------- 11/40 [kiwisolver]
#   Attempting uninstall: idna
#    ----------- ---------------------------- 11/40 [kiwisolver]
#     Found existing installation: idna 3.11
#    ----------- ---------------------------- 11/40 [kiwisolver]
#     Uninstalling idna-3.11:
#    ----------- ---------------------------- 11/40 [kiwisolver]
#       Successfully uninstalled idna-3.11
#    ----------- ---------------------------- 11/40 [kiwisolver]
#    ------------ --------------------------- 12/40 [idna]
#   Attempting uninstall: fonttools
#    ------------ --------------------------- 12/40 [idna]
#     Found existing installation: fonttools 4.60.1
#    ------------ --------------------------- 12/40 [idna]
#    ------------- -------------------------- 13/40 [fonttools]
#     Uninstalling fonttools-4.60.1:
#    ------------- -------------------------- 13/40 [fonttools]
#       Successfully uninstalled fonttools-4.60.1
#    ------------- -------------------------- 13/40 [fonttools]
#    ------------- -------------------------- 13/40 [fonttools]
#    ------------- -------------------------- 13/40 [fonttools]
#    ------------- -------------------------- 13/40 [fonttools]
#    ------------- -------------------------- 13/40 [fonttools]
#    ------------- -------------------------- 13/40 [fonttools]
#    ------------- -------------------------- 13/40 [fonttools]
#    ------------- -------------------------- 13/40 [fonttools]
#    ------------- -------------------------- 13/40 [fonttools]
#   Attempting uninstall: cycler
#    ------------- -------------------------- 13/40 [fonttools]
#     Found existing installation: cycler 0.12.1
#    ------------- -------------------------- 13/40 [fonttools]
#    -------------- ------------------------- 14/40 [cycler]
#     Uninstalling cycler-0.12.1:
#    -------------- ------------------------- 14/40 [cycler]
#       Successfully uninstalled cycler-0.12.1
#    -------------- ------------------------- 14/40 [cycler]
#   Attempting uninstall: colorama
#    -------------- ------------------------- 14/40 [cycler]
#     Found existing installation: colorama 0.4.6
#    -------------- ------------------------- 14/40 [cycler]
#     Uninstalling colorama-0.4.6:
#    -------------- ------------------------- 14/40 [cycler]
#       Successfully uninstalled colorama-0.4.6
#    -------------- ------------------------- 14/40 [cycler]
#   Attempting uninstall: charset_normalizer
#    -------------- ------------------------- 14/40 [cycler]
#     Found existing installation: charset-normalizer 3.4.4
#    -------------- ------------------------- 14/40 [cycler]
#     Uninstalling charset-normalizer-3.4.4:
#    -------------- ------------------------- 14/40 [cycler]
#    ---------------- ----------------------- 16/40 [charset_normalizer]
#       Successfully uninstalled charset-normalizer-3.4.4
#    ---------------- ----------------------- 16/40 [charset_normalizer]
#    ---------------- ----------------------- 16/40 [charset_normalizer]
#    ---------------- ----------------------- 16/40 [charset_normalizer]
#    ---------------- ----------------------- 16/40 [charset_normalizer]
#    ---------------- ----------------------- 16/40 [charset_normalizer]
#    ---------------- ----------------------- 16/40 [charset_normalizer]
#    ---------------- ----------------------- 16/40 [charset_normalizer]
#    ---------------- ----------------------- 16/40 [charset_normalizer]
#    ---------------- ----------------------- 16/40 [charset_normalizer]
#    ---------------- ----------------------- 16/40 [charset_normalizer]
#    ---------------- ----------------------- 16/40 [charset_normalizer]
#    ---------------- ----------------------- 16/40 [charset_normalizer]
#    ---------------- ----------------------- 16/40 [charset_normalizer]
#    ---------------- ----------------------- 16/40 [charset_normalizer]
#    ---------------- ----------------------- 16/40 [charset_normalizer]
#    ---------------- ----------------------- 16/40 [charset_normalizer]
#    ---------------- ----------------------- 16/40 [charset_normalizer]
#    ---------------- ----------------------- 16/40 [charset_normalizer]
#   Attempting uninstall: certifi
#    ---------------- ----------------------- 16/40 [charset_normalizer]
#     Found existing installation: certifi 2025.10.5
#    ---------------- ----------------------- 16/40 [charset_normalizer]
#    ----------------- ---------------------- 17/40 [certifi]
#     Uninstalling certifi-2025.10.5:
#    ----------------- ---------------------- 17/40 [certifi]
#       Successfully uninstalled certifi-2025.10.5
#    ----------------- ---------------------- 17/40 [certifi]
#   Attempting uninstall: attrs
#    ----------------- ---------------------- 17/40 [certifi]
#     Found existing installation: attrs 25.4.0
#    ----------------- ---------------------- 17/40 [certifi]
#     Uninstalling attrs-25.4.0:
#    ----------------- ---------------------- 17/40 [certifi]
#       Successfully uninstalled attrs-25.4.0
#    ----------------- ---------------------- 17/40 [certifi]
#   Attempting uninstall: affine
#    ----------------- ---------------------- 17/40 [certifi]
#     Found existing installation: affine 2.4.0
#    ----------------- ---------------------- 17/40 [certifi]
#     Uninstalling affine-2.4.0:
#    ----------------- ---------------------- 17/40 [certifi]
#       Successfully uninstalled affine-2.4.0
#    ----------------- ---------------------- 17/40 [certifi]
#    ------------------- -------------------- 19/40 [affine]
#   Attempting uninstall: shapely
#    ------------------- -------------------- 19/40 [affine]
#     Found existing installation: shapely 2.1.2
#    ------------------- -------------------- 19/40 [affine]
#     Uninstalling shapely-2.1.2:
#    ------------------- -------------------- 19/40 [affine]
#       Successfully uninstalled shapely-2.1.2
#    ------------------- -------------------- 19/40 [affine]
#    -------------------- ------------------- 20/40 [shapely]
#    -------------------- ------------------- 20/40 [shapely]
#    -------------------- ------------------- 20/40 [shapely]
#    -------------------- ------------------- 20/40 [shapely]
#    -------------------- ------------------- 20/40 [shapely]
#    -------------------- ------------------- 20/40 [shapely]
#    -------------------- ------------------- 20/40 [shapely]
#    -------------------- ------------------- 20/40 [shapely]
#    -------------------- ------------------- 20/40 [shapely]
#    -------------------- ------------------- 20/40 [shapely]
#    -------------------- ------------------- 20/40 [shapely]
#    -------------------- ------------------- 20/40 [shapely]
#    -------------------- ------------------- 20/40 [shapely]
#    -------------------- ------------------- 20/40 [shapely]
#    -------------------- ------------------- 20/40 [shapely]
#    -------------------- ------------------- 20/40 [shapely]
#    -------------------- ------------------- 20/40 [shapely]
#    -------------------- ------------------- 20/40 [shapely]
#    -------------------- ------------------- 20/40 [shapely]
#    -------------------- ------------------- 20/40 [shapely]
#    -------------------- ------------------- 20/40 [shapely]
#    -------------------- ------------------- 20/40 [shapely]
#    -------------------- ------------------- 20/40 [shapely]
#    -------------------- ------------------- 20/40 [shapely]
#    -------------------- ------------------- 20/40 [shapely]
#    -------------------- ------------------- 20/40 [shapely]
#    -------------------- ------------------- 20/40 [shapely]
#    -------------------- ------------------- 20/40 [shapely]
#    -------------------- ------------------- 20/40 [shapely]
#    -------------------- ------------------- 20/40 [shapely]
#    -------------------- ------------------- 20/40 [shapely]
#    -------------------- ------------------- 20/40 [shapely]
#    -------------------- ------------------- 20/40 [shapely]
#    -------------------- ------------------- 20/40 [shapely]
#    -------------------- ------------------- 20/40 [shapely]
#    -------------------- ------------------- 20/40 [shapely]
#    -------------------- ------------------- 20/40 [shapely]
#    -------------------- ------------------- 20/40 [shapely]
#   Attempting uninstall: requests
#    -------------------- ------------------- 20/40 [shapely]
#     Found existing installation: requests 2.32.5
#    -------------------- ------------------- 20/40 [shapely]
#     Uninstalling requests-2.32.5:
#    -------------------- ------------------- 20/40 [shapely]
#       Successfully uninstalled requests-2.32.5
#    -------------------- ------------------- 20/40 [shapely]
#   Attempting uninstall: python-dateutil
#    -------------------- ------------------- 20/40 [shapely]
#     Found existing installation: python-dateutil 2.9.0.post0
#    -------------------- ------------------- 20/40 [shapely]
#     Uninstalling python-dateutil-2.9.0.post0:
#    -------------------- ------------------- 20/40 [shapely]
#       Successfully uninstalled python-dateutil-2.9.0.post0
#    -------------------- ------------------- 20/40 [shapely]
#    ---------------------- ----------------- 22/40 [python-dateutil]
#   Attempting uninstall: pyproj
#    ---------------------- ----------------- 22/40 [python-dateutil]
#     Found existing installation: pyproj 3.4.1
#    ---------------------- ----------------- 22/40 [python-dateutil]
#     Uninstalling pyproj-3.4.1:
#    ---------------------- ----------------- 22/40 [python-dateutil]
#    ----------------------- ---------------- 23/40 [pyproj]
#    ----------------------- ---------------- 23/40 [pyproj]
#   WARNING: Failed to remove contents in a temporary directory 'C:\Users\DELL\anaconda3\envs\tarea3python311\Lib\site-packages\~implejson'.
#   You can safely remove it manually.
#   WARNING: Failed to remove contents in a temporary directory 'C:\Users\DELL\anaconda3\envs\tarea3python311\Lib\site-packages\~il'.
#   You can safely remove it manually.
#   WARNING: Failed to remove contents in a temporary directory 'C:\Users\DELL\anaconda3\envs\tarea3python311\Lib\site-packages\~umpy.libs'.
#   You can safely remove it manually.
#   WARNING: Failed to remove contents in a temporary directory 'C:\Users\DELL\anaconda3\envs\tarea3python311\Lib\site-packages\~umpy'.
#   You can safely remove it manually.
#   WARNING: Failed to remove contents in a temporary directory 'C:\Users\DELL\anaconda3\envs\tarea3python311\Lib\site-packages\~arkupsafe'.
#   You can safely remove it manually.
#   WARNING: Failed to remove contents in a temporary directory 'C:\Users\DELL\anaconda3\envs\tarea3python311\Lib\site-packages\~iwisolver'.
#   You can safely remove it manually.
#   WARNING: Failed to remove contents in a temporary directory 'C:\Users\DELL\anaconda3\envs\tarea3python311\Lib\site-packages\~harset_normalizer'.
#   You can safely remove it manually.
#   WARNING: Failed to remove contents in a temporary directory 'C:\Users\DELL\anaconda3\envs\tarea3python311\Lib\site-packages\~hapely.libs'.
#   You can safely remove it manually.
#   WARNING: Failed to remove contents in a temporary directory 'C:\Users\DELL\anaconda3\envs\tarea3python311\Lib\site-packages\~hapely'.
#   You can safely remove it manually.
# ERROR: Could not install packages due to an OSError: [WinError 5] Acceso denegado: 'c:\\users\\dell\\anaconda3\\envs\\tarea3python311\\lib\\site-packages\\pyproj\\database.cp311-win_amd64.pyd'
# Consider using the `--user` option or check the permissions.

# %%
pip install -r requirements.txt
# Out:
# Collecting numpy<2.3.0,>=1.21.0 (from -r requirements.txt (line 2))
#   Using cached numpy-2.2.6-cp311-cp311-win_amd64.whl.metadata (60 kB)
# Requirement already satisfied: pandas<2.4.0,>=1.5.0 in c:\users\dell\anaconda3\envs\tarea3python311\lib\site-packages (from -r requirements.txt (line 3)) (2.3.3)
# Requirement already satisfied: scipy>=1.9.0 in c:\users\dell\anaconda3\envs\tarea3python311\lib\site-packages (from -r requirements.txt (line 4)) (1.16.2)
# Requirement already satisfied: geopandas<1.0.0,>=0.12.0 in c:\users\dell\anaconda3\envs\tarea3python311\lib\site-packages (from -r requirements.txt (line 7)) (0.14.4)
# Requirement already satisfied: shapely<3.0.0,>=2.0.0 in c:\users\dell\anaconda3\envs\tarea3python311\lib\site-packages (from -r requirements.txt (line 8)) (2.1.2)
# Requirement already satisfied: rasterio<1.4.0,>=1.3.0 in c:\users\dell\anaconda3\envs\tarea3python311\lib\site-packages (from -r requirements.txt (line 9)) (1.3.11)
# Requirement already satisfied: rioxarray<0.20.0,>=0.15.0 in c:\users\dell\anaconda3\envs\tarea3python311\lib\site-packages (from -r requirements.txt (line 10)) (0.18.2)
# Requirement already satisfied: rasterstats>=0.19.0 in c:\users\dell\anaconda3\envs\tarea3python311\lib\site-packages (from -r requirements.txt (line 11)) (0.20.0)
# Collecting pyproj<3.5.0,>=3.0.0 (from -r requirements.txt (line 12))
#   Using cached pyproj-3.4.1-cp311-cp311-win_amd64.whl.metadata (28 kB)
# Requirement already satisfied: geowombat==2.1.22 in c:\users\dell\anaconda3\envs\tarea3python311\lib\site-packages (from -r requirements.txt (line 13)) (2.1.22)
# Requirement already satisfied: folium>=0.14.0 in c:\users\dell\anaconda3\envs\tarea3python311\lib\site-packages (from -r requirements.txt (line 14)) (0.20.0)
# Requirement already satisfied: streamlit<1.36.0,>=1.28.0 in c:\users\dell\anaconda3\envs\tarea3python311\lib\site-packages (from -r requirements.txt (line 17)) (1.35.0)
# Requirement already satisfied: matplotlib<3.9.0,>=3.6.0 in c:\users\dell\anaconda3\envs\tarea3python311\lib\site-packages (from -r requirements.txt (line 18)) (3.8.4)
# Requirement already satisfied: seaborn<0.13.0,>=0.11.2 in c:\users\dell\anaconda3\envs\tarea3python311\lib\site-packages (from -r requirements.txt (line 19)) (0.12.2)
# Requirement already satisfied: plotly<6.0.0,>=5.17.0 in c:\users\dell\anaconda3\envs\tarea3python311\lib\site-packages (from -r requirements.txt (line 20)) (5.24.1)
# Requirement already satisfied: jupyter>=1.0.0 in c:\users\dell\anaconda3\envs\tarea3python311\lib\site-packages (from -r requirements.txt (line 23)) (1.1.1)
# Requirement already satisfied: ipykernel>=6.25.0 in c:\users\dell\anaconda3\envs\tarea3python311\lib\site-packages (from -r requirements.txt (line 24)) (6.30.1)
# Requirement already satisfied: nbformat>=5.7.0 in c:\users\dell\anaconda3\envs\tarea3python311\lib\site-packages (from -r requirements.txt (line 25)) (5.10.4)
# Requirement already satisfied: chardet>=5.0.0 in c:\users\dell\anaconda3\envs\tarea3python311\lib\site-packages (from -r requirements.txt (line 28)) (5.2.0)
# Requirement already satisfied: dask>=2023.1.0 in c:\users\dell\anaconda3\envs\tarea3python311\lib\site-packages (from dask[array,dataframe]>=2023.1.0->geowombat==2.1.22->-r requirements.txt (line 13)) (2025.10.0)
# Requirement already satisfied: distributed>=2023.1.0 in c:\users\dell\anaconda3\envs\tarea3python311\lib\site-packages (from geowombat==2.1.22->-r requirements.txt (line 13)) (2025.10.0)
# Requirement already satisfied: joblib>=0.16.0 in c:\users\dell\anaconda3\envs\tarea3python311\lib\site-packages (from geowombat==2.1.22->-r requirements.txt (line 13)) (1.5.2)
# Requirement already satisfied: retry in c:\users\dell\anaconda3\envs\tarea3python311\lib\site-packages (from geowombat==2.1.22->-r requirements.txt (line 13)) (0.9.2)
# Requirement already satisfied: requests>=2.20.0 in c:\users\dell\anaconda3\envs\tarea3python311\lib\site-packages (from geowombat==2.1.22->-r requirements.txt (line 13)) (2.32.5)
# Requirement already satisfied: scikit-learn>=0.23.0 in c:\users\dell\anaconda3\envs\tarea3python311\lib\site-packages (from geowombat==2.1.22->-r requirements.txt (line 13)) (1.7.2)
# Requirement already satisfied: tqdm>=4.62.0 in c:\users\dell\anaconda3\envs\tarea3python311\lib\site-packages (from geowombat==2.1.22->-r requirements.txt (line 13)) (4.67.1)
# Requirement already satisfied: xarray>=2023.1.0 in c:\users\dell\anaconda3\envs\tarea3python311\lib\site-packages (from geowombat==2.1.22->-r requirements.txt (line 13)) (2025.10.1)
# Requirement already satisfied: h5netcdf>=1.0.2 in c:\users\dell\anaconda3\envs\tarea3python311\lib\site-packages (from geowombat==2.1.22->-r requirements.txt (line 13)) (1.7.2)
# Requirement already satisfied: cryptography>=38.0.0 in c:\users\dell\anaconda3\envs\tarea3python311\lib\site-packages (from geowombat==2.1.22->-r requirements.txt (line 13)) (46.0.3)
# Requirement already satisfied: threadpoolctl>=3.1.0 in c:\users\dell\anaconda3\envs\tarea3python311\lib\site-packages (from geowombat==2.1.22->-r requirements.txt (line 13)) (3.6.0)
# Requirement already satisfied: setuptools>=59.5.0 in c:\users\dell\anaconda3\envs\tarea3python311\lib\site-packages (from geowombat==2.1.22->-r requirements.txt (line 13)) (80.9.0)
# Requirement already satisfied: cython<3.0.0,>=0.29.0 in c:\users\dell\anaconda3\envs\tarea3python311\lib\site-packages (from geowombat==2.1.22->-r requirements.txt (line 13)) (0.29.37)
# Requirement already satisfied: python-dateutil>=2.8.2 in c:\users\dell\anaconda3\envs\tarea3python311\lib\site-packages (from pandas<2.4.0,>=1.5.0->-r requirements.txt (line 3)) (2.9.0.post0)
# Requirement already satisfied: pytz>=2020.1 in c:\users\dell\anaconda3\envs\tarea3python311\lib\site-packages (from pandas<2.4.0,>=1.5.0->-r requirements.txt (line 3)) (2025.2)
# Requirement already satisfied: tzdata>=2022.7 in c:\users\dell\anaconda3\envs\tarea3python311\lib\site-packages (from pandas<2.4.0,>=1.5.0->-r requirements.txt (line 3)) (2025.2)
# Requirement already satisfied: fiona>=1.8.21 in c:\users\dell\anaconda3\envs\tarea3python311\lib\site-packages (from geopandas<1.0.0,>=0.12.0->-r requirements.txt (line 7)) (1.10.1)
# Requirement already satisfied: packaging in c:\users\dell\anaconda3\envs\tarea3python311\lib\site-packages (from geopandas<1.0.0,>=0.12.0->-r requirements.txt (line 7)) (25.0)
# Requirement already satisfied: affine in c:\users\dell\anaconda3\envs\tarea3python311\lib\site-packages (from rasterio<1.4.0,>=1.3.0->-r requirements.txt (line 9)) (2.4.0)
# Requirement already satisfied: attrs in c:\users\dell\anaconda3\envs\tarea3python311\lib\site-packages (from rasterio<1.4.0,>=1.3.0->-r requirements.txt (line 9)) (25.4.0)
# Requirement already satisfied: certifi in c:\users\dell\anaconda3\envs\tarea3python311\lib\site-packages (from rasterio<1.4.0,>=1.3.0->-r requirements.txt (line 9)) (2025.10.5)
# Requirement already satisfied: click>=4.0 in c:\users\dell\anaconda3\envs\tarea3python311\lib\site-packages (from rasterio<1.4.0,>=1.3.0->-r requirements.txt (line 9)) (8.3.0)
# Requirement already satisfied: cligj>=0.5 in c:\users\dell\anaconda3\envs\tarea3python311\lib\site-packages (from rasterio<1.4.0,>=1.3.0->-r requirements.txt (line 9)) (0.7.2)
# Requirement already satisfied: snuggs>=1.4.1 in c:\users\dell\anaconda3\envs\tarea3python311\lib\site-packages (from rasterio<1.4.0,>=1.3.0->-r requirements.txt (line 9)) (1.4.7)
# Requirement already satisfied: click-plugins in c:\users\dell\anaconda3\envs\tarea3python311\lib\site-packages (from rasterio<1.4.0,>=1.3.0->-r requirements.txt (line 9)) (1.1.1.2)
# Requirement already satisfied: altair<6,>=4.0 in c:\users\dell\anaconda3\envs\tarea3python311\lib\site-packages (from streamlit<1.36.0,>=1.28.0->-r requirements.txt (line 17)) (5.5.0)
# Requirement already satisfied: blinker<2,>=1.0.0 in c:\users\dell\anaconda3\envs\tarea3python311\lib\site-packages (from streamlit<1.36.0,>=1.28.0->-r requirements.txt (line 17)) (1.9.0)
# Requirement already satisfied: cachetools<6,>=4.0 in c:\users\dell\anaconda3\envs\tarea3python311\lib\site-packages (from streamlit<1.36.0,>=1.28.0->-r requirements.txt (line 17)) (5.5.2)
# Collecting numpy<2.3.0,>=1.21.0 (from -r requirements.txt (line 2))
#   Using cached numpy-1.26.4-cp311-cp311-win_amd64.whl.metadata (61 kB)
# Collecting packaging (from geopandas<1.0.0,>=0.12.0->-r requirements.txt (line 7))
#   Using cached packaging-24.2-py3-none-any.whl.metadata (3.2 kB)
# Collecting pillow<11,>=7.1.0 (from streamlit<1.36.0,>=1.28.0->-r requirements.txt (line 17))
#   Using cached pillow-10.4.0-cp311-cp311-win_amd64.whl.metadata (9.3 kB)
# Requirement already satisfied: protobuf<5,>=3.20 in c:\users\dell\anaconda3\envs\tarea3python311\lib\site-packages (from streamlit<1.36.0,>=1.28.0->-r requirements.txt (line 17)) (4.25.8)
# Requirement already satisfied: pyarrow>=7.0 in c:\users\dell\anaconda3\envs\tarea3python311\lib\site-packages (from streamlit<1.36.0,>=1.28.0->-r requirements.txt (line 17)) (21.0.0)
# Requirement already satisfied: rich<14,>=10.14.0 in c:\users\dell\anaconda3\envs\tarea3python311\lib\site-packages (from streamlit<1.36.0,>=1.28.0->-r requirements.txt (line 17)) (13.9.4)
# Requirement already satisfied: tenacity<9,>=8.1.0 in c:\users\dell\anaconda3\envs\tarea3python311\lib\site-packages (from streamlit<1.36.0,>=1.28.0->-r requirements.txt (line 17)) (8.5.0)
# Requirement already satisfied: toml<2,>=0.10.1 in c:\users\dell\anaconda3\envs\tarea3python311\lib\site-packages (from streamlit<1.36.0,>=1.28.0->-r requirements.txt (line 17)) (0.10.2)
# Requirement already satisfied: typing-extensions<5,>=4.3.0 in c:\users\dell\anaconda3\envs\tarea3python311\lib\site-packages (from streamlit<1.36.0,>=1.28.0->-r requirements.txt (line 17)) (4.15.0)
# Requirement already satisfied: gitpython!=3.1.19,<4,>=3.0.7 in c:\users\dell\anaconda3\envs\tarea3python311\lib\site-packages (from streamlit<1.36.0,>=1.28.0->-r requirements.txt (line 17)) (3.1.45)
# Requirement already satisfied: pydeck<1,>=0.8.0b4 in c:\users\dell\anaconda3\envs\tarea3python311\lib\site-packages (from streamlit<1.36.0,>=1.28.0->-r requirements.txt (line 17)) (0.9.1)
# Requirement already satisfied: tornado<7,>=6.0.3 in c:\users\dell\anaconda3\envs\tarea3python311\lib\site-packages (from streamlit<1.36.0,>=1.28.0->-r requirements.txt (line 17)) (6.5.1)
# Requirement already satisfied: watchdog>=2.1.5 in c:\users\dell\anaconda3\envs\tarea3python311\lib\site-packages (from streamlit<1.36.0,>=1.28.0->-r requirements.txt (line 17)) (6.0.0)
# Requirement already satisfied: contourpy>=1.0.1 in c:\users\dell\anaconda3\envs\tarea3python311\lib\site-packages (from matplotlib<3.9.0,>=3.6.0->-r requirements.txt (line 18)) (1.3.3)
# Requirement already satisfied: cycler>=0.10 in c:\users\dell\anaconda3\envs\tarea3python311\lib\site-packages (from matplotlib<3.9.0,>=3.6.0->-r requirements.txt (line 18)) (0.12.1)
# Requirement already satisfied: fonttools>=4.22.0 in c:\users\dell\anaconda3\envs\tarea3python311\lib\site-packages (from matplotlib<3.9.0,>=3.6.0->-r requirements.txt (line 18)) (4.60.1)
# Requirement already satisfied: kiwisolver>=1.3.1 in c:\users\dell\anaconda3\envs\tarea3python311\lib\site-packages (from matplotlib<3.9.0,>=3.6.0->-r requirements.txt (line 18)) (1.4.9)
# Requirement already satisfied: pyparsing>=2.3.1 in c:\users\dell\anaconda3\envs\tarea3python311\lib\site-packages (from matplotlib<3.9.0,>=3.6.0->-r requirements.txt (line 18)) (3.2.5)
# Requirement already satisfied: jinja2 in c:\users\dell\anaconda3\envs\tarea3python311\lib\site-packages (from altair<6,>=4.0->streamlit<1.36.0,>=1.28.0->-r requirements.txt (line 17)) (3.1.6)
# Requirement already satisfied: jsonschema>=3.0 in c:\users\dell\anaconda3\envs\tarea3python311\lib\site-packages (from altair<6,>=4.0->streamlit<1.36.0,>=1.28.0->-r requirements.txt (line 17)) (4.25.0)
# Requirement already satisfied: narwhals>=1.14.2 in c:\users\dell\anaconda3\envs\tarea3python311\lib\site-packages (from altair<6,>=4.0->streamlit<1.36.0,>=1.28.0->-r requirements.txt (line 17)) (2.8.0)
# Requirement already satisfied: colorama in c:\users\dell\anaconda3\envs\tarea3python311\lib\site-packages (from click>=4.0->rasterio<1.4.0,>=1.3.0->-r requirements.txt (line 9)) (0.4.6)
# Requirement already satisfied: gitdb<5,>=4.0.1 in c:\users\dell\anaconda3\envs\tarea3python311\lib\site-packages (from gitpython!=3.1.19,<4,>=3.0.7->streamlit<1.36.0,>=1.28.0->-r requirements.txt (line 17)) (4.0.12)
# Requirement already satisfied: smmap<6,>=3.0.1 in c:\users\dell\anaconda3\envs\tarea3python311\lib\site-packages (from gitdb<5,>=4.0.1->gitpython!=3.1.19,<4,>=3.0.7->streamlit<1.36.0,>=1.28.0->-r requirements.txt (line 17)) (5.0.2)
# Requirement already satisfied: charset_normalizer<4,>=2 in c:\users\dell\anaconda3\envs\tarea3python311\lib\site-packages (from requests>=2.20.0->geowombat==2.1.22->-r requirements.txt (line 13)) (3.4.4)
# Requirement already satisfied: idna<4,>=2.5 in c:\users\dell\anaconda3\envs\tarea3python311\lib\site-packages (from requests>=2.20.0->geowombat==2.1.22->-r requirements.txt (line 13)) (3.11)
# Requirement already satisfied: urllib3<3,>=1.21.1 in c:\users\dell\anaconda3\envs\tarea3python311\lib\site-packages (from requests>=2.20.0->geowombat==2.1.22->-r requirements.txt (line 13)) (2.5.0)
# Requirement already satisfied: markdown-it-py>=2.2.0 in c:\users\dell\anaconda3\envs\tarea3python311\lib\site-packages (from rich<14,>=10.14.0->streamlit<1.36.0,>=1.28.0->-r requirements.txt (line 17)) (4.0.0)
# Requirement already satisfied: pygments<3.0.0,>=2.13.0 in c:\users\dell\anaconda3\envs\tarea3python311\lib\site-packages (from rich<14,>=10.14.0->streamlit<1.36.0,>=1.28.0->-r requirements.txt (line 17)) (2.19.1)
# Requirement already satisfied: simplejson in c:\users\dell\anaconda3\envs\tarea3python311\lib\site-packages (from rasterstats>=0.19.0->-r requirements.txt (line 11)) (3.20.2)
# Requirement already satisfied: branca>=0.6.0 in c:\users\dell\anaconda3\envs\tarea3python311\lib\site-packages (from folium>=0.14.0->-r requirements.txt (line 14)) (0.8.2)
# Requirement already satisfied: xyzservices in c:\users\dell\anaconda3\envs\tarea3python311\lib\site-packages (from folium>=0.14.0->-r requirements.txt (line 14)) (2025.4.0)
# Requirement already satisfied: notebook in c:\users\dell\anaconda3\envs\tarea3python311\lib\site-packages (from jupyter>=1.0.0->-r requirements.txt (line 23)) (7.4.5)
# Requirement already satisfied: jupyter-console in c:\users\dell\anaconda3\envs\tarea3python311\lib\site-packages (from jupyter>=1.0.0->-r requirements.txt (line 23)) (6.6.3)
# Requirement already satisfied: nbconvert in c:\users\dell\anaconda3\envs\tarea3python311\lib\site-packages (from jupyter>=1.0.0->-r requirements.txt (line 23)) (7.16.6)
# Requirement already satisfied: ipywidgets in c:\users\dell\anaconda3\envs\tarea3python311\lib\site-packages (from jupyter>=1.0.0->-r requirements.txt (line 23)) (8.1.7)
# Requirement already satisfied: jupyterlab in c:\users\dell\anaconda3\envs\tarea3python311\lib\site-packages (from jupyter>=1.0.0->-r requirements.txt (line 23)) (4.4.7)
# Requirement already satisfied: comm>=0.1.1 in c:\users\dell\anaconda3\envs\tarea3python311\lib\site-packages (from ipykernel>=6.25.0->-r requirements.txt (line 24)) (0.2.1)
# Requirement already satisfied: debugpy>=1.6.5 in c:\users\dell\anaconda3\envs\tarea3python311\lib\site-packages (from ipykernel>=6.25.0->-r requirements.txt (line 24)) (1.8.16)
# Requirement already satisfied: ipython>=7.23.1 in c:\users\dell\anaconda3\envs\tarea3python311\lib\site-packages (from ipykernel>=6.25.0->-r requirements.txt (line 24)) (9.5.0)
# Requirement already satisfied: jupyter-client>=8.0.0 in c:\users\dell\anaconda3\envs\tarea3python311\lib\site-packages (from ipykernel>=6.25.0->-r requirements.txt (line 24)) (8.6.3)
# Requirement already satisfied: jupyter-core!=5.0.*,>=4.12 in c:\users\dell\anaconda3\envs\tarea3python311\lib\site-packages (from ipykernel>=6.25.0->-r requirements.txt (line 24)) (5.8.1)
# Requirement already satisfied: matplotlib-inline>=0.1 in c:\users\dell\anaconda3\envs\tarea3python311\lib\site-packages (from ipykernel>=6.25.0->-r requirements.txt (line 24)) (0.1.7)
# Requirement already satisfied: nest-asyncio>=1.4 in c:\users\dell\anaconda3\envs\tarea3python311\lib\site-packages (from ipykernel>=6.25.0->-r requirements.txt (line 24)) (1.6.0)
# Requirement already satisfied: psutil>=5.7 in c:\users\dell\anaconda3\envs\tarea3python311\lib\site-packages (from ipykernel>=6.25.0->-r requirements.txt (line 24)) (7.0.0)
# Requirement already satisfied: pyzmq>=25 in c:\users\dell\anaconda3\envs\tarea3python311\lib\site-packages (from ipykernel>=6.25.0->-r requirements.txt (line 24)) (27.1.0)
# Requirement already satisfied: traitlets>=5.4.0 in c:\users\dell\anaconda3\envs\tarea3python311\lib\site-packages (from ipykernel>=6.25.0->-r requirements.txt (line 24)) (5.14.3)
# Requirement already satisfied: fastjsonschema>=2.15 in c:\users\dell\anaconda3\envs\tarea3python311\lib\site-packages (from nbformat>=5.7.0->-r requirements.txt (line 25)) (2.20.0)
# Requirement already satisfied: cffi>=1.14 in c:\users\dell\anaconda3\envs\tarea3python311\lib\site-packages (from cryptography>=38.0.0->geowombat==2.1.22->-r requirements.txt (line 13)) (2.0.0)
# Requirement already satisfied: pycparser in c:\users\dell\anaconda3\envs\tarea3python311\lib\site-packages (from cffi>=1.14->cryptography>=38.0.0->geowombat==2.1.22->-r requirements.txt (line 13)) (2.23)
# Requirement already satisfied: cloudpickle>=3.0.0 in c:\users\dell\anaconda3\envs\tarea3python311\lib\site-packages (from dask>=2023.1.0->dask[array,dataframe]>=2023.1.0->geowombat==2.1.22->-r requirements.txt (line 13)) (3.1.1)
# Requirement already satisfied: fsspec>=2021.09.0 in c:\users\dell\anaconda3\envs\tarea3python311\lib\site-packages (from dask>=2023.1.0->dask[array,dataframe]>=2023.1.0->geowombat==2.1.22->-r requirements.txt (line 13)) (2025.9.0)
# Requirement already satisfied: partd>=1.4.0 in c:\users\dell\anaconda3\envs\tarea3python311\lib\site-packages (from dask>=2023.1.0->dask[array,dataframe]>=2023.1.0->geowombat==2.1.22->-r requirements.txt (line 13)) (1.4.2)
# Requirement already satisfied: pyyaml>=5.3.1 in c:\users\dell\anaconda3\envs\tarea3python311\lib\site-packages (from dask>=2023.1.0->dask[array,dataframe]>=2023.1.0->geowombat==2.1.22->-r requirements.txt (line 13)) (6.0.2)
# Requirement already satisfied: toolz>=0.10.0 in c:\users\dell\anaconda3\envs\tarea3python311\lib\site-packages (from dask>=2023.1.0->dask[array,dataframe]>=2023.1.0->geowombat==2.1.22->-r requirements.txt (line 13)) (1.1.0)
# Requirement already satisfied: importlib_metadata>=4.13.0 in c:\users\dell\anaconda3\envs\tarea3python311\lib\site-packages (from dask>=2023.1.0->dask[array,dataframe]>=2023.1.0->geowombat==2.1.22->-r requirements.txt (line 13)) (8.7.0)
# Requirement already satisfied: locket>=1.0.0 in c:\users\dell\anaconda3\envs\tarea3python311\lib\site-packages (from distributed>=2023.1.0->geowombat==2.1.22->-r requirements.txt (line 13)) (1.0.0)
# Requirement already satisfied: msgpack>=1.0.2 in c:\users\dell\anaconda3\envs\tarea3python311\lib\site-packages (from distributed>=2023.1.0->geowombat==2.1.22->-r requirements.txt (line 13)) (1.1.2)
# Requirement already satisfied: sortedcontainers>=2.0.5 in c:\users\dell\anaconda3\envs\tarea3python311\lib\site-packages (from distributed>=2023.1.0->geowombat==2.1.22->-r requirements.txt (line 13)) (2.4.0)
# Requirement already satisfied: tblib>=1.6.0 in c:\users\dell\anaconda3\envs\tarea3python311\lib\site-packages (from distributed>=2023.1.0->geowombat==2.1.22->-r requirements.txt (line 13)) (3.1.0)
# Requirement already satisfied: zict>=3.0.0 in c:\users\dell\anaconda3\envs\tarea3python311\lib\site-packages (from distributed>=2023.1.0->geowombat==2.1.22->-r requirements.txt (line 13)) (3.0.0)
# Requirement already satisfied: h5py in c:\users\dell\anaconda3\envs\tarea3python311\lib\site-packages (from h5netcdf>=1.0.2->geowombat==2.1.22->-r requirements.txt (line 13)) (3.8.0)
# Requirement already satisfied: zipp>=3.20 in c:\users\dell\anaconda3\envs\tarea3python311\lib\site-packages (from importlib_metadata>=4.13.0->dask>=2023.1.0->dask[array,dataframe]>=2023.1.0->geowombat==2.1.22->-r requirements.txt (line 13)) (3.23.0)
# Requirement already satisfied: decorator in c:\users\dell\anaconda3\envs\tarea3python311\lib\site-packages (from ipython>=7.23.1->ipykernel>=6.25.0->-r requirements.txt (line 24)) (5.2.1)
# Requirement already satisfied: ipython-pygments-lexers in c:\users\dell\anaconda3\envs\tarea3python311\lib\site-packages (from ipython>=7.23.1->ipykernel>=6.25.0->-r requirements.txt (line 24)) (1.1.1)
# Requirement already satisfied: jedi>=0.16 in c:\users\dell\anaconda3\envs\tarea3python311\lib\site-packages (from ipython>=7.23.1->ipykernel>=6.25.0->-r requirements.txt (line 24)) (0.19.2)
# Requirement already satisfied: prompt_toolkit<3.1.0,>=3.0.41 in c:\users\dell\anaconda3\envs\tarea3python311\lib\site-packages (from ipython>=7.23.1->ipykernel>=6.25.0->-r requirements.txt (line 24)) (3.0.52)
# Requirement already satisfied: stack_data in c:\users\dell\anaconda3\envs\tarea3python311\lib\site-packages (from ipython>=7.23.1->ipykernel>=6.25.0->-r requirements.txt (line 24)) (0.6.3)
# Requirement already satisfied: wcwidth in c:\users\dell\anaconda3\envs\tarea3python311\lib\site-packages (from prompt_toolkit<3.1.0,>=3.0.41->ipython>=7.23.1->ipykernel>=6.25.0->-r requirements.txt (line 24)) (0.2.13)
# Requirement already satisfied: parso<0.9.0,>=0.8.4 in c:\users\dell\anaconda3\envs\tarea3python311\lib\site-packages (from jedi>=0.16->ipython>=7.23.1->ipykernel>=6.25.0->-r requirements.txt (line 24)) (0.8.4)
# Requirement already satisfied: MarkupSafe>=2.0 in c:\users\dell\anaconda3\envs\tarea3python311\lib\site-packages (from jinja2->altair<6,>=4.0->streamlit<1.36.0,>=1.28.0->-r requirements.txt (line 17)) (3.0.3)
# Requirement already satisfied: jsonschema-specifications>=2023.03.6 in c:\users\dell\anaconda3\envs\tarea3python311\lib\site-packages (from jsonschema>=3.0->altair<6,>=4.0->streamlit<1.36.0,>=1.28.0->-r requirements.txt (line 17)) (2023.7.1)
# Requirement already satisfied: referencing>=0.28.4 in c:\users\dell\anaconda3\envs\tarea3python311\lib\site-packages (from jsonschema>=3.0->altair<6,>=4.0->streamlit<1.36.0,>=1.28.0->-r requirements.txt (line 17)) (0.30.2)
# Requirement already satisfied: rpds-py>=0.7.1 in c:\users\dell\anaconda3\envs\tarea3python311\lib\site-packages (from jsonschema>=3.0->altair<6,>=4.0->streamlit<1.36.0,>=1.28.0->-r requirements.txt (line 17)) (0.22.3)
# Requirement already satisfied: platformdirs>=2.5 in c:\users\dell\anaconda3\envs\tarea3python311\lib\site-packages (from jupyter-core!=5.0.*,>=4.12->ipykernel>=6.25.0->-r requirements.txt (line 24)) (4.3.7)
# Requirement already satisfied: pywin32>=300 in c:\users\dell\anaconda3\envs\tarea3python311\lib\site-packages (from jupyter-core!=5.0.*,>=4.12->ipykernel>=6.25.0->-r requirements.txt (line 24)) (311)
# Requirement already satisfied: mdurl~=0.1 in c:\users\dell\anaconda3\envs\tarea3python311\lib\site-packages (from markdown-it-py>=2.2.0->rich<14,>=10.14.0->streamlit<1.36.0,>=1.28.0->-r requirements.txt (line 17)) (0.1.2)
# Requirement already satisfied: six>=1.5 in c:\users\dell\anaconda3\envs\tarea3python311\lib\site-packages (from python-dateutil>=2.8.2->pandas<2.4.0,>=1.5.0->-r requirements.txt (line 3)) (1.17.0)
# Requirement already satisfied: widgetsnbextension~=4.0.14 in c:\users\dell\anaconda3\envs\tarea3python311\lib\site-packages (from ipywidgets->jupyter>=1.0.0->-r requirements.txt (line 23)) (4.0.14)
# Requirement already satisfied: jupyterlab_widgets~=3.0.15 in c:\users\dell\anaconda3\envs\tarea3python311\lib\site-packages (from ipywidgets->jupyter>=1.0.0->-r requirements.txt (line 23)) (3.0.15)
# Requirement already satisfied: async-lru>=1.0.0 in c:\users\dell\anaconda3\envs\tarea3python311\lib\site-packages (from jupyterlab->jupyter>=1.0.0->-r requirements.txt (line 23)) (2.0.4)
# Requirement already satisfied: httpx<1,>=0.25.0 in c:\users\dell\anaconda3\envs\tarea3python311\lib\site-packages (from jupyterlab->jupyter>=1.0.0->-r requirements.txt (line 23)) (0.28.1)
# Requirement already satisfied: jupyter-lsp>=2.0.0 in c:\users\dell\anaconda3\envs\tarea3python311\lib\site-packages (from jupyterlab->jupyter>=1.0.0->-r requirements.txt (line 23)) (2.2.5)
# Requirement already satisfied: jupyter-server<3,>=2.4.0 in c:\users\dell\anaconda3\envs\tarea3python311\lib\site-packages (from jupyterlab->jupyter>=1.0.0->-r requirements.txt (line 23)) (2.16.0)
# Requirement already satisfied: jupyterlab-server<3,>=2.27.1 in c:\users\dell\anaconda3\envs\tarea3python311\lib\site-packages (from jupyterlab->jupyter>=1.0.0->-r requirements.txt (line 23)) (2.27.3)
# Requirement already satisfied: notebook-shim>=0.2 in c:\users\dell\anaconda3\envs\tarea3python311\lib\site-packages (from jupyterlab->jupyter>=1.0.0->-r requirements.txt (line 23)) (0.2.4)
# Requirement already satisfied: anyio in c:\users\dell\anaconda3\envs\tarea3python311\lib\site-packages (from httpx<1,>=0.25.0->jupyterlab->jupyter>=1.0.0->-r requirements.txt (line 23)) (4.10.0)
# Requirement already satisfied: httpcore==1.* in c:\users\dell\anaconda3\envs\tarea3python311\lib\site-packages (from httpx<1,>=0.25.0->jupyterlab->jupyter>=1.0.0->-r requirements.txt (line 23)) (1.0.9)
# Requirement already satisfied: h11>=0.16 in c:\users\dell\anaconda3\envs\tarea3python311\lib\site-packages (from httpcore==1.*->httpx<1,>=0.25.0->jupyterlab->jupyter>=1.0.0->-r requirements.txt (line 23)) (0.16.0)
# Requirement already satisfied: argon2-cffi>=21.1 in c:\users\dell\anaconda3\envs\tarea3python311\lib\site-packages (from jupyter-server<3,>=2.4.0->jupyterlab->jupyter>=1.0.0->-r requirements.txt (line 23)) (21.3.0)
# Requirement already satisfied: jupyter-events>=0.11.0 in c:\users\dell\anaconda3\envs\tarea3python311\lib\site-packages (from jupyter-server<3,>=2.4.0->jupyterlab->jupyter>=1.0.0->-r requirements.txt (line 23)) (0.12.0)
# Requirement already satisfied: jupyter-server-terminals>=0.4.4 in c:\users\dell\anaconda3\envs\tarea3python311\lib\site-packages (from jupyter-server<3,>=2.4.0->jupyterlab->jupyter>=1.0.0->-r requirements.txt (line 23)) (0.5.3)
# Requirement already satisfied: overrides>=5.0 in c:\users\dell\anaconda3\envs\tarea3python311\lib\site-packages (from jupyter-server<3,>=2.4.0->jupyterlab->jupyter>=1.0.0->-r requirements.txt (line 23)) (7.4.0)
# Requirement already satisfied: prometheus-client>=0.9 in c:\users\dell\anaconda3\envs\tarea3python311\lib\site-packages (from jupyter-server<3,>=2.4.0->jupyterlab->jupyter>=1.0.0->-r requirements.txt (line 23)) (0.21.1)
# Requirement already satisfied: pywinpty>=2.0.1 in c:\users\dell\anaconda3\envs\tarea3python311\lib\site-packages (from jupyter-server<3,>=2.4.0->jupyterlab->jupyter>=1.0.0->-r requirements.txt (line 23)) (2.0.15)
# Requirement already satisfied: send2trash>=1.8.2 in c:\users\dell\anaconda3\envs\tarea3python311\lib\site-packages (from jupyter-server<3,>=2.4.0->jupyterlab->jupyter>=1.0.0->-r requirements.txt (line 23)) (1.8.2)
# Requirement already satisfied: terminado>=0.8.3 in c:\users\dell\anaconda3\envs\tarea3python311\lib\site-packages (from jupyter-server<3,>=2.4.0->jupyterlab->jupyter>=1.0.0->-r requirements.txt (line 23)) (0.18.1)
# Requirement already satisfied: websocket-client>=1.7 in c:\users\dell\anaconda3\envs\tarea3python311\lib\site-packages (from jupyter-server<3,>=2.4.0->jupyterlab->jupyter>=1.0.0->-r requirements.txt (line 23)) (1.8.0)
# Requirement already satisfied: babel>=2.10 in c:\users\dell\anaconda3\envs\tarea3python311\lib\site-packages (from jupyterlab-server<3,>=2.27.1->jupyterlab->jupyter>=1.0.0->-r requirements.txt (line 23)) (2.16.0)
# Requirement already satisfied: json5>=0.9.0 in c:\users\dell\anaconda3\envs\tarea3python311\lib\site-packages (from jupyterlab-server<3,>=2.27.1->jupyterlab->jupyter>=1.0.0->-r requirements.txt (line 23)) (0.9.25)
# Requirement already satisfied: sniffio>=1.1 in c:\users\dell\anaconda3\envs\tarea3python311\lib\site-packages (from anyio->httpx<1,>=0.25.0->jupyterlab->jupyter>=1.0.0->-r requirements.txt (line 23)) (1.3.0)
# Requirement already satisfied: argon2-cffi-bindings in c:\users\dell\anaconda3\envs\tarea3python311\lib\site-packages (from argon2-cffi>=21.1->jupyter-server<3,>=2.4.0->jupyterlab->jupyter>=1.0.0->-r requirements.txt (line 23)) (25.1.0)
# Requirement already satisfied: python-json-logger>=2.0.4 in c:\users\dell\anaconda3\envs\tarea3python311\lib\site-packages (from jupyter-events>=0.11.0->jupyter-server<3,>=2.4.0->jupyterlab->jupyter>=1.0.0->-r requirements.txt (line 23)) (3.2.1)
# Requirement already satisfied: rfc3339-validator in c:\users\dell\anaconda3\envs\tarea3python311\lib\site-packages (from jupyter-events>=0.11.0->jupyter-server<3,>=2.4.0->jupyterlab->jupyter>=1.0.0->-r requirements.txt (line 23)) (0.1.4)
# Requirement already satisfied: rfc3986-validator>=0.1.1 in c:\users\dell\anaconda3\envs\tarea3python311\lib\site-packages (from jupyter-events>=0.11.0->jupyter-server<3,>=2.4.0->jupyterlab->jupyter>=1.0.0->-r requirements.txt (line 23)) (0.1.1)
# Requirement already satisfied: fqdn in c:\users\dell\anaconda3\envs\tarea3python311\lib\site-packages (from jsonschema[format-nongpl]>=4.18.0->jupyter-events>=0.11.0->jupyter-server<3,>=2.4.0->jupyterlab->jupyter>=1.0.0->-r requirements.txt (line 23)) (1.5.1)
# Requirement already satisfied: isoduration in c:\users\dell\anaconda3\envs\tarea3python311\lib\site-packages (from jsonschema[format-nongpl]>=4.18.0->jupyter-events>=0.11.0->jupyter-server<3,>=2.4.0->jupyterlab->jupyter>=1.0.0->-r requirements.txt (line 23)) (20.11.0)
# Requirement already satisfied: jsonpointer>1.13 in c:\users\dell\anaconda3\envs\tarea3python311\lib\site-packages (from jsonschema[format-nongpl]>=4.18.0->jupyter-events>=0.11.0->jupyter-server<3,>=2.4.0->jupyterlab->jupyter>=1.0.0->-r requirements.txt (line 23)) (3.0.0)
# Requirement already satisfied: rfc3987-syntax>=1.1.0 in c:\users\dell\anaconda3\envs\tarea3python311\lib\site-packages (from jsonschema[format-nongpl]>=4.18.0->jupyter-events>=0.11.0->jupyter-server<3,>=2.4.0->jupyterlab->jupyter>=1.0.0->-r requirements.txt (line 23)) (1.1.0)
# Requirement already satisfied: uri-template in c:\users\dell\anaconda3\envs\tarea3python311\lib\site-packages (from jsonschema[format-nongpl]>=4.18.0->jupyter-events>=0.11.0->jupyter-server<3,>=2.4.0->jupyterlab->jupyter>=1.0.0->-r requirements.txt (line 23)) (1.3.0)
# Requirement already satisfied: webcolors>=24.6.0 in c:\users\dell\anaconda3\envs\tarea3python311\lib\site-packages (from jsonschema[format-nongpl]>=4.18.0->jupyter-events>=0.11.0->jupyter-server<3,>=2.4.0->jupyterlab->jupyter>=1.0.0->-r requirements.txt (line 23)) (24.11.1)
# Requirement already satisfied: beautifulsoup4 in c:\users\dell\anaconda3\envs\tarea3python311\lib\site-packages (from nbconvert->jupyter>=1.0.0->-r requirements.txt (line 23)) (4.13.5)
# Requirement already satisfied: bleach!=5.0.0 in c:\users\dell\anaconda3\envs\tarea3python311\lib\site-packages (from bleach[css]!=5.0.0->nbconvert->jupyter>=1.0.0->-r requirements.txt (line 23)) (6.2.0)
# Requirement already satisfied: defusedxml in c:\users\dell\anaconda3\envs\tarea3python311\lib\site-packages (from nbconvert->jupyter>=1.0.0->-r requirements.txt (line 23)) (0.7.1)
# Requirement already satisfied: jupyterlab-pygments in c:\users\dell\anaconda3\envs\tarea3python311\lib\site-packages (from nbconvert->jupyter>=1.0.0->-r requirements.txt (line 23)) (0.3.0)
# Requirement already satisfied: mistune<4,>=2.0.3 in c:\users\dell\anaconda3\envs\tarea3python311\lib\site-packages (from nbconvert->jupyter>=1.0.0->-r requirements.txt (line 23)) (3.1.2)
# Requirement already satisfied: nbclient>=0.5.0 in c:\users\dell\anaconda3\envs\tarea3python311\lib\site-packages (from nbconvert->jupyter>=1.0.0->-r requirements.txt (line 23)) (0.10.2)
# Requirement already satisfied: pandocfilters>=1.4.1 in c:\users\dell\anaconda3\envs\tarea3python311\lib\site-packages (from nbconvert->jupyter>=1.0.0->-r requirements.txt (line 23)) (1.5.1)
# Requirement already satisfied: webencodings in c:\users\dell\anaconda3\envs\tarea3python311\lib\site-packages (from bleach!=5.0.0->bleach[css]!=5.0.0->nbconvert->jupyter>=1.0.0->-r requirements.txt (line 23)) (0.5.1)
# Requirement already satisfied: tinycss2<1.5,>=1.1.0 in c:\users\dell\anaconda3\envs\tarea3python311\lib\site-packages (from bleach[css]!=5.0.0->nbconvert->jupyter>=1.0.0->-r requirements.txt (line 23)) (1.4.0)
# Requirement already satisfied: lark>=1.2.2 in c:\users\dell\anaconda3\envs\tarea3python311\lib\site-packages (from rfc3987-syntax>=1.1.0->jsonschema[format-nongpl]>=4.18.0->jupyter-events>=0.11.0->jupyter-server<3,>=2.4.0->jupyterlab->jupyter>=1.0.0->-r requirements.txt (line 23)) (1.3.0)
# Requirement already satisfied: soupsieve>1.2 in c:\users\dell\anaconda3\envs\tarea3python311\lib\site-packages (from beautifulsoup4->nbconvert->jupyter>=1.0.0->-r requirements.txt (line 23)) (2.5)
# Requirement already satisfied: arrow>=0.15.0 in c:\users\dell\anaconda3\envs\tarea3python311\lib\site-packages (from isoduration->jsonschema[format-nongpl]>=4.18.0->jupyter-events>=0.11.0->jupyter-server<3,>=2.4.0->jupyterlab->jupyter>=1.0.0->-r requirements.txt (line 23)) (1.3.0)
# Requirement already satisfied: types-python-dateutil>=2.8.10 in c:\users\dell\anaconda3\envs\tarea3python311\lib\site-packages (from arrow>=0.15.0->isoduration->jsonschema[format-nongpl]>=4.18.0->jupyter-events>=0.11.0->jupyter-server<3,>=2.4.0->jupyterlab->jupyter>=1.0.0->-r requirements.txt (line 23)) (2.9.0.20251008)
# Requirement already satisfied: py<2.0.0,>=1.4.26 in c:\users\dell\anaconda3\envs\tarea3python311\lib\site-packages (from retry->geowombat==2.1.22->-r requirements.txt (line 13)) (1.11.0)
# Requirement already satisfied: executing>=1.2.0 in c:\users\dell\anaconda3\envs\tarea3python311\lib\site-packages (from stack_data->ipython>=7.23.1->ipykernel>=6.25.0->-r requirements.txt (line 24)) (2.2.1)
# Requirement already satisfied: asttokens>=2.1.0 in c:\users\dell\anaconda3\envs\tarea3python311\lib\site-packages (from stack_data->ipython>=7.23.1->ipykernel>=6.25.0->-r requirements.txt (line 24)) (3.0.0)
# Requirement already satisfied: pure_eval in c:\users\dell\anaconda3\envs\tarea3python311\lib\site-packages (from stack_data->ipython>=7.23.1->ipykernel>=6.25.0->-r requirements.txt (line 24)) (0.2.3)
# Using cached pyproj-3.4.1-cp311-cp311-win_amd64.whl (4.8 MB)
# Using cached numpy-1.26.4-cp311-cp311-win_amd64.whl (15.8 MB)
# Using cached packaging-24.2-py3-none-any.whl (65 kB)
# Using cached pillow-10.4.0-cp311-cp311-win_amd64.whl (2.6 MB)
# Installing collected packages: pyproj, pillow, packaging, numpy
#
#    ---------------------------------------- 0/4 [pyproj]
#
# Note: you may need to restart the kernel to use updated packages.
# WARNING: Ignoring invalid distribution ~yproj (C:\Users\DELL\anaconda3\envs\tarea3python311\Lib\site-packages)
# WARNING: Ignoring invalid distribution ~yproj (C:\Users\DELL\anaconda3\envs\tarea3python311\Lib\site-packages)
# ERROR: Could not install packages due to an OSError: [WinError 5] Acceso denegado: 'C:\\Users\\DELL\\anaconda3\\envs\\tarea3python311\\Lib\\site-packages\\pyproj\\database.cp311-win_amd64.pyd'
# Consider using the `--user` option or check the permissions.

# %%
import geopandas as gpd
import rioxarray
import rasterio
from rasterstats import zonal_stats
import matplotlib.pyplot as plt
import pandas as pd
import numpy as np
import folium

# %%
# Upload shape file at district level

maps = gpd.read_file(r'_data/shape_file/DISTRITOS.shp')
# Muestra las primeras 5 filas de tu tabla
maps.head()
# Dibuja un mapa básico de los distritos
maps.plot()
# Out:
# <Axes: >

# %%
maps.crs
# Out:
# <Geographic 2D CRS: EPSG:4326>
# Name: WGS 84
# Axis Info [ellipsoidal]:
# - Lat[north]: Geodetic latitude (degree)
# - Lon[east]: Geodetic longitude (degree)
# Area of Use:
# - name: World.
# - bounds: (-180.0, -90.0, 180.0, 90.0)
# Datum: World Geodetic System 1984 ensemble
# - Ellipsoid: WGS 84
# - Prime Meridian: Greenwich

# %%
maps.columns
# Out:
# Index(['IDDPTO', 'DEPARTAMEN', 'IDPROV', 'PROVINCIA', 'IDDIST', 'DISTRITO',
#        'CAPITAL', 'CODCCPP', 'AREA', 'FUENTE', 'geometry'],
#       dtype='object')

# %%
# Asegura que todas las columnas estén en mayúsculas 
maps.columns = maps.columns.str.upper()

# Limpieza de acentos y estandarización del nombre del distrito
maps['DISTRITO'] = (
    maps['DISTRITO']
    .str.normalize('NFKD')
    .str.encode('ascii', errors='ignore')
    .str.decode('utf-8')
    .str.upper()
)

# Verifica los primeros valores
maps.head()
# Out:
#   IDDPTO DEPARTAMEN IDPROV    PROVINCIA  IDDIST                DISTRITO  \
# 0     10    HUANUCO   1009  PUERTO INCA  100902         CODO DEL POZUZO
# 1     10    HUANUCO   1009  PUERTO INCA  100904             TOURNAVISTA
# 2     25    UCAYALI   2503   PADRE ABAD  250305  ALEXANDER VON HUMBOLDT
# 3     25    UCAYALI   2503   PADRE ABAD  250302                 IRAZOLA
# 4     25    UCAYALI   2503   PADRE ABAD  250304                 NESHUYA
#
#                   CAPITAL CODCCPP  AREA FUENTE  \
# 0         CODO DEL POZUZO    0001     1   INEI
# 1             TOURNAVISTA    0001     1   INEI
# 2  ALEXANDER VON HUMBOLDT    0001     1   INEI
# 3           SAN ALEJANDRO    0001     1   INEI
# 4            MONTE ALEGRE    0001     1   INEI
#
#                                             GEOMETRY
# 0  POLYGON ((-75.31797 -9.29529, -75.31710 -9.297...
# 1  POLYGON ((-74.64136 -8.82302, -74.64036 -8.828...
# 2  POLYGON ((-75.02253 -8.74193, -75.02267 -8.742...
# 3  POLYGON ((-75.13864 -8.56712, -75.13956 -8.569...
# 4  POLYGON ((-75.01589 -8.44637, -75.01585 -8.446...

# %%
import geopandas as gpd
import rioxarray
from rasterstats import zonal_stats
import pandas as pd
import numpy as np

# %%
# Carga el raster Tmin
tmin_raster = rioxarray.open_rasterio("tmin_raster.tif")

# Si es multibanda (por ejemplo, una banda por año o mes)
print(tmin_raster)
# Out:
# <xarray.DataArray (band: 5, y: 397, x: 285)> Size: 2MB
# [565725 values with dtype=float32]
# Coordinates:
#   * band         (band) int64 40B 1 2 3 4 5
#   * y            (y) float64 3kB 1.175 1.125 1.075 ... -18.53 -18.58 -18.63
#   * x            (x) float64 2kB -81.35 -81.3 -81.25 ... -67.26 -67.21 -67.16
#     spatial_ref  int64 8B 0
# Attributes:
#     AREA_OR_POINT:  Area
#     scale_factor:   1.0
#     add_offset:     0.0

# %%
import os
os.makedirs("../data", exist_ok=True)

# %% [markdown]
# # 3.2 — Zonal statistics

# %%
import geopandas as gpd
import pandas as pd
from rasterstats import zonal_stats
import rioxarray

maps = maps.set_geometry("GEOMETRY")


# Asegura que ambos CRS coincidan
if maps.crs != tmin_raster.rio.crs:
    maps = maps.to_crs(tmin_raster.rio.crs)

# --- Cálculo por banda ---
results = []

for i in range(1, len(tmin_raster.band) + 1):  # bandas 1 a 5
    print(f"Procesando banda {i}...")
    
    # Guarda temporalmente la banda i
    temp_file = f"../data/temp_band_{i}.tif"
    # Espeficiar no data
    tmin_raster.sel(band=i).rio.to_raster(temp_file, nodata=-9999999999999999)    
    # Calcula estadísticas para esa banda
    stats = zonal_stats(
        vectors=maps,
        raster=temp_file,
        stats=["count", "mean", "min", "max", "std", "percentile_10", "percentile_90"],
        geojson_out=False
    )
    
    # Convierte a DataFrame y añade la etiqueta de banda
    df_band = pd.DataFrame(stats)
    df_band["banda"] = i
    df_band["UBIGEO"] = maps["IDDIST"]
    df_band["DISTRITO"] = maps["DISTRITO"]
    df_band["PROVINCIA"] = maps["PROVINCIA"]
    df_band["DEPARTAMEN"] = maps["DEPARTAMEN"]
    
    results.append(df_band)

# --- Combina todo ---
zonal_df = pd.concat(results, ignore_index=True)

# Calcula un rango térmico intra-distrital: Métrica personalizada
zonal_df["range_temp"] = zonal_df["max"] - zonal_df["min"]

# Guarda los resultados
zonal_df.to_csv("../data/zonal_tmin_bandas.csv", index=False)

print("✅ Listo: estadísticas zonales por distrito y por banda calculadas.")
zonal_df.head()
# Out:
# Procesando banda 1...
# Procesando banda 2...
# Procesando banda 3...
# Procesando banda 4...
# Procesando banda 5...
# ✅ Listo: estadísticas zonales por distrito y por banda calculadas.
#          min        max       mean  count       std  percentile_10  \
# 0   8.903979  22.604116  18.932154    107  3.430219      13.836891
# 1  19.775057  22.860834  22.290649     57  0.464426      21.992695
# 2  21.953405  22.141968  22.056366      6  0.076649      21.955791
# 3  21.661476  22.481043  22.263211     62  0.158932      22.042723
# 4  21.975763  22.385101  22.173068     22  0.118299      22.023388
#
#    percentile_90  banda  UBIGEO                DISTRITO    PROVINCIA  \
# 0      22.358988      1  100902         CODO DEL POZUZO  PUERTO INCA
# 1      22.676195      1  100904             TOURNAVISTA  PUERTO INCA
# 2      22.137794      1  250305  ALEXANDER VON HUMBOLDT   PADRE ABAD
# 3      22.416752      1  250302                 IRAZOLA   PADRE ABAD
# 4      22.361992      1  250304                 NESHUYA   PADRE ABAD
#
#   DEPARTAMEN  range_temp
# 0    HUANUCO   13.700137
# 1    HUANUCO    3.085777
# 2    UCAYALI    0.188562
# 3    UCAYALI    0.819567
# 4    UCAYALI    0.409338

# %%
tmin_raster.mean().values
# Data is in actual °C
# Out:
# array(17.823227, dtype=float32)

# %% [markdown]
# # 3.3 — Analysis & Visualizations

# %%
import pandas as pd

zonal_df = pd.read_csv("../data/zonal_tmin_bandas.csv", dtype={"UBIGEO": str})

zonal_df.head()
# Out:
#          min        max       mean  count       std  percentile_10  \
# 0   8.903979  22.604116  18.932154    107  3.430219      13.836891
# 1  19.775057  22.860834  22.290649     57  0.464426      21.992695
# 2  21.953405  22.141968  22.056366      6  0.076649      21.955791
# 3  21.661476  22.481043  22.263211     62  0.158932      22.042723
# 4  21.975763  22.385101  22.173068     22  0.118299      22.023388
#
#    percentile_90  banda  UBIGEO                DISTRITO    PROVINCIA  \
# 0      22.358988      1  100902         CODO DEL POZUZO  PUERTO INCA
# 1      22.676195      1  100904             TOURNAVISTA  PUERTO INCA
# 2      22.137794      1  250305  ALEXANDER VON HUMBOLDT   PADRE ABAD
# 3      22.416752      1  250302                 IRAZOLA   PADRE ABAD
# 4      22.361992      1  250304                 NESHUYA   PADRE ABAD
#
#   DEPARTAMEN  range_temp
# 0    HUANUCO   13.700137
# 1    HUANUCO    3.085777
# 2    UCAYALI    0.188562
# 3    UCAYALI    0.819567
# 4    UCAYALI    0.409338

# %%
zonal_df["mean"].describe()
# Out:
# count    8945.000000
# mean        9.453099
# std         6.880738
# min        -5.989168
# 25%         3.941030
# 50%         8.444639
# 75%        15.180823
# max        23.294387
# Name: mean, dtype: float64

# %%
zonal_mean = (
    zonal_df.groupby(["UBIGEO", "DISTRITO", "PROVINCIA", "DEPARTAMEN"])
    .agg({"mean": "mean", "min": "mean", "max": "mean"})
    .reset_index()
)

# %%
zonal_mean
# Out:
#       UBIGEO                DISTRITO    PROVINCIA DEPARTAMEN       mean  \
# 0     010101             CHACHAPOYAS  CHACHAPOYAS   AMAZONAS  12.403868
# 1     010102                ASUNCION  CHACHAPOYAS   AMAZONAS  10.232676
# 2     010103                  BALSAS  CHACHAPOYAS   AMAZONAS  14.492733
# 3     010104                   CHETO  CHACHAPOYAS   AMAZONAS  11.770264
# 4     010105               CHILIQUIN  CHACHAPOYAS   AMAZONAS  11.065167
# ...      ...                     ...          ...        ...        ...
# 1868  250302                 IRAZOLA   PADRE ABAD    UCAYALI  22.097315
# 1869  250303                CURIMANA   PADRE ABAD    UCAYALI  22.027528
# 1870  250304                 NESHUYA   PADRE ABAD    UCAYALI  21.937903
# 1871  250305  ALEXANDER VON HUMBOLDT   PADRE ABAD    UCAYALI  21.862907
# 1872  250401                   PURUS        PURUS    UCAYALI  21.863619
#
#             min        max
# 0     11.032648  13.120787
# 1     10.029134  10.436218
# 2      9.164226  18.931234
# 3     11.627967  11.850517
# 4      9.423780  12.711129
# ...         ...        ...
# 1868  21.486948  22.322860
# 1869  21.757619  22.194360
# 1870  21.727421  22.180375
# 1871  21.730026  21.946946
# 1872  21.466217  22.127753
#
# [1873 rows x 7 columns]

# %%
import matplotlib.pyplot as plt

plt.figure(figsize=(8,5))
plt.hist(zonal_mean["mean"], bins=30, color="skyblue", edgecolor="black")
plt.title("Distribución de temperatura mínima media distrital (°C)")
plt.xlabel("Temperatura mínima media (°C)")
plt.ylabel("Frecuencia")
plt.show()

# %%
top15 = zonal_mean.nlargest(15, "mean")
bottom15 = zonal_mean.nsmallest(15, "mean")

print("Distritos más cálidos:")
display(top15[["DISTRITO", "mean"]])
print("\nDistritos más fríos:")
display(bottom15[["DISTRITO", "mean"]])
# Out:
# Distritos más cálidos:
#             DISTRITO       mean
# 1496          MORONA  23.008980
# 1502          YAGUAS  23.005028
# 1472  RAMON CASTILLA  22.972547
# 1475       SAN PABLO  22.934505
# 1497         PASTAZA  22.919820
# 1473           PEBAS  22.878973
# 1454    LAS AMAZONAS  22.814834
# 1450         IQUITOS  22.780908
# 1499        PUTUMAYO  22.779239
# 1453         INDIANA  22.761415
# 1474          YAVARI  22.747571
# 1464         LAGUNAS  22.745657
# 1457        PUNCHANA  22.717702
# 1467           NAUTA  22.706026
# 1471        URARINAS  22.699432
# Distritos más fríos:
#                   DISTRITO      mean
# 1676                CAPAZO -5.191071
# 1840              SUSAPAYA -5.157803
# 1835                TARATA -4.995736
# 1678            SANTA ROSA -4.861880
# 1842                TICACO -4.417395
# 411   SAN ANTONIO DE CHUCA -4.390306
# 1826             CANDARAVE -4.359307
# 753              CONDOROMA -4.122947
# 1694               PARATIA -4.094575
# 1515               CARUMAS -3.411975
# 352   SAN JUAN DE TARUCANI -3.343182
# 415                   TUTI -3.258119
# 1672              PISACOMA -3.248725
# 1659               AJOYANI -3.141027
# 1696           SANTA LUCIA -3.063950

# %%
import geopandas as gpd
import matplotlib.pyplot as plt

# 1 Cargar el shapefile
maps = gpd.read_file("_data/shape_file/DISTRITOS.shp")

if "UBIGEO" not in maps.columns and "IDDIST" in maps.columns:
    maps["UBIGEO"] = maps["IDDIST"]
# 2️ Estandarizar nombres de columnas (por si acaso)
maps.columns = maps.columns.str.upper()


# 2.5 Estandarizar nombres de distritos

maps['DISTRITO'] = (
    maps['DISTRITO']
    .str.normalize('NFKD')
    .str.encode('ascii', errors='ignore')
    .str.decode('utf-8')
    .str.strip()
    .str.upper()
)


# 3️ Verificar nombre de columna geográfica y activarla
if "GEOMETRY" in maps.columns:
    maps = maps.set_geometry("GEOMETRY")

# 4️ Definir CRS si no está
if maps.crs is None:
    maps.set_crs("EPSG:4326", inplace=True)

# 5️ Hacer el merge con tus datos zonales (usa la media o el df que quieras)
maps["UBIGEO"] = maps["UBIGEO"].astype(str)
zonal_mean["UBIGEO"] = zonal_mean["UBIGEO"].astype(str)
map_merge = maps.merge(zonal_mean, on="UBIGEO", how="left")
map_merge = map_merge.rename(columns={
    "DISTRITO_x": "DISTRITO",
    "PROVINCIA_x": "PROVINCIA",
    "DEPARTAMEN_x": "DEPARTAMEN"
}).drop(columns=["DISTRITO_y", "PROVINCIA_y", "DEPARTAMEN_y"], errors="ignore")
# 6️ Asegurar que conserve geometría y CRS después del merge
map_merge = gpd.GeoDataFrame(map_merge, geometry="GEOMETRY", crs=maps.crs)

# Coropletas con datos perdidos
fig, ax = plt.subplots(1, 1, figsize=(8, 8))

# Temperatura
map_merge[map_merge["mean"].notna()].plot(
    column="mean",
    cmap="coolwarm",
    legend=True,
    ax=ax
)

# Overlay districts with missing data in gray
map_merge[map_merge["mean"].isna()].plot(
    color="lightgray",
    edgecolor="black",
    ax=ax
)

plt.title("Temperatura mínima media por distrito (°C)")
plt.axis("off")
plt.show()

#Carpeta
os.makedirs("../outputs", exist_ok=True)

# Guardamos el mapa
fig.savefig("../outputs/choropleth_distritos.png", dpi=300, bbox_inches='tight')
plt.close(fig)  # Close the figure to free memory


# Guardamas la tabla como CSV
map_merge.drop(columns="GEOMETRY").to_csv("../outputs/distritos_temperatura.csv", index=False)

print("✅ PNG map saved to '../outputs/choropleth_distritos.png'")
print("✅ CSV table saved to '../outputs/distritos_temperatura.csv'")
# Out:
# ✅ PNG map saved to '../outputs/choropleth_distritos.png'
# ✅ CSV table saved to '../outputs/distritos_temperatura.csv'

# %%
# 7️ Graficar
fig, ax = plt.subplots(1, 1, figsize=(8, 8))
map_merge.plot(column="mean", cmap="coolwarm", legend=True, ax=ax)
plt.title("Temperatura mínima media por distrito (°C)")
plt.axis("off")
plt.show()

# %%
# --- Choropleth with gray for missing data ---
fig, ax = plt.subplots(1, 1, figsize=(10, 10))

# Plot districts with temperature data
map_merge[map_merge["mean"].notna()].plot(
    column="mean",
    cmap="coolwarm",
    legend=True,
    ax=ax
)

# Overlay districts with missing data in gray
map_merge[map_merge["mean"].isna()].plot(
    color="lightgray",
    edgecolor="black",
    ax=ax
)

plt.title("Temperatura mínima media por distrito (°C)")
plt.axis("off")
plt.show()

# %%
print("maps:", len(maps))
print("zonal_mean:", len(zonal_mean))
# Out:
# maps: 1873
# zonal_mean: 1873
